# %% [markdown]
# <a href="https://colab.research.google.com/github/anandnanda/PythonBasics/blob/main/PyToBeNoted.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('2') if 2>1  else print('1')
# Out:
# 2

# %%
[print(x) for x in [1,2,3,4]]
# Out:
# 1
# 2
# 3
# 4
# [None, None, None, None]

# %%
#'short form of comparison'
a=10
b=11
print(a) if a>b else print('=') if a==b else print(b)
# Out:
# 11
