# %% [markdown]
# <a href="https://colab.research.google.com/github/anandnanda/PythonBasics/blob/main/PythonBasics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Python programming.....")
# Out:
# Python programming.....

# %%
#import packages
import sys

# %%
print(' Python version:', sys.version)  #  Python version
# Out:
#  Python version: 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %%
print("print....")
print('line1', end=" ")
print('this is line', 2 , "after line1")
# Out:
# print....
# line1 this is line 2 after line1

# %%
print('comment...')
"""
this is
multiple line comment
printed as such in output
"""
# single line comment
# Out:
# comment...
# '\nthis is\nmultiple line comment\nprinted as such in output\n'

# %%
print('variables declaration.....')
x=2
y=2.5
z='string'
b=True
X="|this is diff from x;"
_x="this is also diff from x"
a,b,c=2,3,4
d=f=2,3
print(x,y,z,b,X,_x)
print(a,b,c)
print(d,f)
fruits = ["apple", "banana", "cherry"]
i,o,p = fruits
print(i,o,p)
# Out:
# variables declaration.....
# 2 2.5 string 3 |this is diff from x; this is also diff from x
# 2 3 4
# (2, 3) (2, 3)
# apple banana cherry

# %%
print('type & conversion....')
print(type(X), type(x), type(y))
print(int(y))
print(float('4.78'))
print(str(y))
# Out:
# type & conversion....
# <class 'str'> <class 'int'> <class 'float'>
# 2
# 4.78
# 2.5

# %%
#global var
x=4
def myFunc():
  print(x)

def myFunc2():
  x=2
  print(x)

def myFunc3():
  global y
  y=2


myFunc()
myFunc2()
myFunc3(); print(y)
# Out:
# 4
# 2
# 2

# %%
from typing import FrozenSet
"""
Data Types
Text Type:	str
Numeric Types:	int, float, complex
Sequence Types:	list, tuple, range
Mapping Type:	dict
Set Types:	set, frozenset
Boolean Type:	bool
Binary Types:	bytes, bytearray, memoryview
None Type:	NoneType
"""
s1="this is string"
n1=3 #int
n2=3.5 #float
n3=3+5j #complex

lst=[1,2,3,3]
tple = (1,2,3,4)
rng = range(5)

dic={'one':1, 'two':2, 'three':3}
set1={1,2,3,4,4}  #duplicate 4 will be discarded
frozenSet=frozenset({1,2,3,4})

bol=False
bolByte=b'hello'
bolByteArray=bytearray(5)
bolMemoryView=memoryview(bytes(5))

noneType=None

print(s1,n1,n2,n3)

print("List: " , lst); print("Tuple:", tple); print('range:', rng)
print("Set:", set1)
print("Frozen Set:", frozenSet)
print('dictionary', dic)
print('element in each of above....')
print(lst[2])
print(tple[2])
print(dic['two'])
print('set....')
for st in set1: #indexing not allowed in set
  print(st)

print(bol, bolByte, bolByteArray, bolMemoryView)

print(noneType)
# Out:
# this is string 3 3.5 (3+5j)
# List:  [1, 2, 3, 3]
# Tuple: (1, 2, 3, 4)
# range: range(0, 5)
# Set: {1, 2, 3, 4}
# Frozen Set: frozenset({1, 2, 3, 4})
# dictionary {'one': 1, 'two': 2, 'three': 3}
# element in each of above....
# 3
# 3
# 2
# set....
# 1
# 2
# 3
# 4
# False b'hello' bytearray(b'\x00\x00\x00\x00\x00') <memory at 0x7be0ee04a080>
# None

# %%
# type conversion of above data types
print(int('4'))
print(float('5.7'))
print(str(3))
com=complex(3+5j)
print(com)
print(list([1,2,3,3]))
print(tuple ((1,2,3,4)))
print( range(5))
print(dict({'one':1, 'two':2, 'three':3}))
print(set({1,2,3,4}))
print(complex(2))
# Out:
# 4
# 5.7
# 3
# (3+5j)
# [1, 2, 3, 3]
# (1, 2, 3, 4)
# range(0, 5)
# {'one': 1, 'two': 2, 'three': 3}
# {1, 2, 3, 4}
# (2+0j)

# %%
#tple[0]=6 #err - tuple cant be changed
# set1[0]=6 #err 'set' object does not support item assignment
# set1[0]=2 #err
set1.add(5) #add allowed but not edit
print(set1)
# Out:
# {1, 2, 3, 4, 5}

# %%
def add_two_numbers(num1, num2):
  """This function takes two numbers as input and returns their sum."""
  return num1 + num2

# Example usage:
result = add_two_numbers(5, 3)
print(f"The sum is: {result}")
# Out:
# The sum is: 8

# %%
#random
import random
rnd=random.randrange(1,5) # can take any no from 1 to 4 discarding last digit
print(rnd)
# Out:
# 2

# %%
#strings
s0="string"
print(s0)
s1="""
This is
multiple line
string
"""
print(s1)
s2='''This is
also multiple
line string'''
print(s2)

s3="'string' highlight"
print(s3)

for s in "ABC":
  print(s)

print(len(s0))

if 'also' in s2:
  print('also  present in s2')
else:
  print('also NOT present in s2')
# Out:
# string
#
# This is
# multiple line
# string
#
# This is
# also multiple
# line string
# 'string' highlight
# A
# B
# C
# 6
# also  present in s2

# %%
#string slicing
ss="ThisIsSlicingString"
print(ss[2:5])
print(ss[:5])
print(ss[2:])
print(ss[2:-1])
print(ss[-2:])
print(ss[-5:-6])  #nothing will be printed
print(ss[-5:-1])
# Out:
# isI
# ThisI
# isIsSlicingString
# isIsSlicingStrin
# ng
#
# trin

# %%
#string modify
print(ss.upper())
print(ss.lower())
print(ss.replace('S', 's'))
s4=ss.split('is')
print(s4, type(s4))
s4=ss.split('Is')
print(s4)
# Out:
# THISISSLICINGSTRING
# thisisslicingstring
# ThisIsslicingstring
# ['Th', 'IsSlicingString'] <class 'list'>
# ['This', 'SlicingString']

# %%
#string format
x11=12
s5="this is string"
#print(s5 + x11) # --> err - can only concatenate str (not "int") to str
print(s5 + str(x11))
print(s5, x11)
print(f'{s5} , {x11}')
print(f'{x11:.3f}')
# Out:
# this is string12
# this is string 12
# this is string , 12
# 12.000

# %%
# string escape characters
"""
sdf
\'	Single Quote
\\	Backslash
\n	New Line
\r	Carriage Return
\t	Tab
\b	Backspace
\f	Form Feed
\ooo	Octal value
\ x hh	Hex value
"""
# Out:
# <>:11: SyntaxWarning: invalid escape sequence '\o'
# <>:11: SyntaxWarning: invalid escape sequence '\o'
# /tmp/ipython-input-809546569.py:11: SyntaxWarning: invalid escape sequence '\o'
#   \ooo	Octal value
# "\nsdf\n'\tSingle Quote\t\n\\\tBackslash\t\n\n\tNew Line\t\n\r\tCarriage Return\t\n\t\tTab\t\n\x08\tBackspace\t\n\x0c\tForm Feed\t\n\\ooo\tOctal value\t\n\\ x hh\tHex value\n"

# %%
"""String Keywords
capitalize()	Converts the first character to upper case
casefold()	Converts string into lower case
center()	Returns a centered string
count()	Returns the number of times a specified value occurs in a string
encode()	Returns an encoded version of the string
endswith()	Returns true if the string ends with the specified value
expandtabs()	Sets the tab size of the string
find()	Searches the string for a specified value and returns the position of where it was found
format()	Formats specified values in a string
format_map()	Formats specified values in a string
index()	Searches the string for a specified value and returns the position of where it was found
isalnum()	Returns True if all characters in the string are alphanumeric
isalpha()	Returns True if all characters in the string are in the alphabet
isascii()	Returns True if all characters in the string are ascii characters
isdecimal()	Returns True if all characters in the string are decimals
isdigit()	Returns True if all characters in the string are digits
isidentifier()	Returns True if the string is an identifier
islower()	Returns True if all characters in the string are lower case
isnumeric()	Returns True if all characters in the string are numeric
isprintable()	Returns True if all characters in the string are printable
isspace()	Returns True if all characters in the string are whitespaces
istitle()	Returns True if the string follows the rules of a title
isupper()	Returns True if all characters in the string are upper case
join()	Joins the elements of an iterable to the end of the string
ljust()	Returns a left justified version of the string
lower()	Converts a string into lower case
lstrip()	Returns a left trim version of the string
maketrans()	Returns a translation table to be used in translations
partition()	Returns a tuple where the string is parted into three parts
replace()	Returns a string where a specified value is replaced with a specified value
rfind()	Searches the string for a specified value and returns the last position of where it was found
rindex()	Searches the string for a specified value and returns the last position of where it was found
rjust()	Returns a right justified version of the string
rpartition()	Returns a tuple where the string is parted into three parts
rsplit()	Splits the string at the specified separator, and returns a list
rstrip()	Returns a right trim version of the string
split()	Splits the string at the specified separator, and returns a list
splitlines()	Splits the string at line breaks and returns a list
startswith()	Returns true if the string starts with the specified value
strip()	Returns a trimmed version of the string
swapcase()	Swaps cases, lower case becomes upper case and vice versa
title()	Converts the first character of each word to upper case
translate()	Returns a translated string
upper()	Converts a string into upper case
zfill()	Fills the string with a specified number of 0 values at the beginning
"""
# Out:
# 'String Keywords\ncapitalize()\tConverts the first character to upper case\ncasefold()\tConverts string into lower case\ncenter()\tReturns a centered string\ncount()\tReturns the number of times a specified value occurs in a string\nencode()\tReturns an encoded version of the string\nendswith()\tReturns true if the string ends with the specified value\nexpandtabs()\tSets the tab size of the string\nfind()\tSearches the string for a specified value and returns the position of where it was found\nformat()\tFormats specified values in a string\nformat_map()\tFormats specified values in a string\nindex()\tSearches the string for a specified value and returns the position of where it was found\nisalnum()\tReturns True if all characters in the string are alphanumeric\nisalpha()\tReturns True if all characters in the string are in the alphabet\nisascii()\tReturns True if all characters in the string are ascii characters\nisdecimal()\tReturns True if all characters in the string are decimals
# ...

# %%
#Boolean
b1 = "Hello"
b2 = 15
b3=False

print(bool(b1))
print(bool(b2))
print(b3)
print( bool(None), bool(0), bool(""), bool(()), bool([]), bool({}))

b4 = 200
print(isinstance(b4, int))

def Fun1():
  return True
print(Fun1())

class myclass():
  def __len__(self):
    return 0

myobj = myclass()
print(bool(myobj))
# Out:
# True
# True
# False
# False False False False False False
# True
# True
# False

# %%
"""operators
Arithmetic operators
Assignment operators
Comparison operators
Logical operators
Identity operators
Membership operators
Bitwise operators
"""
#Arithmetic
"""
+	Addition	x + y
-	Subtraction	x - y
*	Multiplication	x * y
/	Division	x / y
%	Modulus	x % y
**	Exponentiation	x ** y
//	Floor division	x // y
"""
print(10+5)
print(10-5)
print(10*5)
print(5/2)
print(5%2)
print(5//2)
print(5**2)
# Out:
# 15
# 5
# 50
# 2.5
# 1
# 2
# 25

# %%
"""Assignment operator
Operator	Example	Same As	Try it
=	x = 5	x = 5
+=	x += 3	x = x + 3
-=	x -= 3	x = x - 3
*=	x *= 3	x = x * 3
/=	x /= 3	x = x / 3
%=	x %= 3	x = x % 3
//=	x //= 3	x = x // 3
**=	x **= 3	x = x ** 3
&=	x &= 3	x = x & 3
|=	x |= 3	x = x | 3
^=	x ^= 3	x = x ^ 3
>>=	x >>= 3	x = x >> 3
<<=	x <<= 3	x = x << 3
:=	print(x := 3)	x = 3   -- Walrus Operator
print(x)
"""
a1=9
print(a1^3)
print(x := len("string"))
# Out:
# 10
# 6

# %%
# Identity Operators  > True if both variables point to the same object
"""
is - Checks if both variables point to the same object in memory
== - Checks if the values of both variables are equal
"""
l1=[1,2]
l2=[3,4]
l3=[1,2]
l4=l1
t1=(1,2)
print(l1 is t1)
print(l1 is l2)
print(l1 is l3)
print(l4 is l1)
# Out:
# False
# False
# False
# True

# %%
#membership oprator
print(1 in [1,2,3])
print(1 not in [1,2,3])
# Out:
# True
# False

# %%
""" Bitwise operator
& 	AND	Sets each bit to 1 if both bits are 1	x & y
|	OR	Sets each bit to 1 if one of two bits is 1	x | y
^	XOR	Sets each bit to 1 if only one of two bits is 1	x ^ y
~	NOT	Inverts all the bits	~x
<<	Zero fill left shift	Shift left by pushing zeros in from the right and let the leftmost bits fall off	x << 2
>>	Signed right shift	Shift right by pushing copies of the leftmost bit in from the left, and let the rightmost bits fall off	x >
"""
print(True & False)
print(True | False)
print(True ^ False)
print(1^2)
print(~True)
print(2<<1)
print(2>>1)
# Out:
# False
# True
# True
# 3
# -2
# 4
# 1
