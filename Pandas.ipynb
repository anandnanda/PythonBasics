# %% [markdown]
# <a href="https://colab.research.google.com/github/anandnanda/PythonBasics/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas
#
# Pandas is a Python library used for working with data sets.
#
# It has functions for analyzing, cleaning, exploring, and manipulating data.

# %%
import pandas as pd

# Replace with the raw URL of your CSV file on GitHub
github_csv_url = 'https://raw.githubusercontent.com/anandnanda/PythonBasics/main/Sample.csv'

df=pd.read_csv(github_csv_url)
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.5
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
try:
    df = pd.read_csv(github_csv_url1)
    print("Successfully loaded CSV file from GitHub:")
    display(df.head())
except Exception as e:
    print(f"Error loading CSV file: {e}\nPlease ensure the URL is correct and the file is accessible.")
# Out:
# Error loading CSV file: name 'github_csv_url1' is not defined
# Please ensure the URL is correct and the file is accessible.

# %%
df.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
ds={
    'cars': ["Ford","Tata"],
    'Mileage': [10,20]
}
df=pd.DataFrame(ds)
print(ds)
# Out:
# {'cars': ['Ford', 'Tata'], 'Mileage': [10, 20]}

# %%
df.Mileage
# Out:
# 0    10
# 1    20
# Name: Mileage, dtype: int64

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %%
a=[2,3,5]
ser=pd.Series(a)
print(ser)
print(pd.Series(df.cars))
print(pd.Series(df.Mileage))
# Out:
# 0    2
# 1    3
# 2    5
# dtype: int64
# 0    Ford
# 1    Tata
# Name: cars, dtype: object
# 0    10
# 1    20
# Name: Mileage, dtype: int64

# %%
print(df.loc[0])
# Out:
# cars       Ford
# Mileage      10
# Name: 0, dtype: object

# %%
print(a[0])
# Out:
# 2

# %%
#create index
a=[2,3,5]
aIndex=pd.Series(a,index=['x','y','z'])
print(aIndex)
# Out:
# x    2
# y    3
# z    5
# dtype: int64

# %%
print(aIndex['x'])
# Out:
# 2

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}
print(pd.Series(calories))
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
print(pd.Series(calories,index=['day1','day3']))
# Out:
# day1    420
# day3    390
# dtype: int64

# %% [markdown]
# #DataFrames
# Data sets in Pandas are usually multi-dimensional tables, called DataFrames.
#
# Series is like a column, a DataFrame is the whole table.

# %%
ds={
    'cars': ["Ford","Tata",'Kia'],
    'Mileage': [10,20,30]
}
df=pd.DataFrame(ds)
print(ds)
# Out:
# {'cars': ['Ford', 'Tata', 'Kia'], 'Mileage': [10, 20, 30]}

# %%
print(df.loc[0])
# Out:
# cars       Ford
# Mileage      10
# Name: 0, dtype: object

# %%
print(df.loc[[0,2]])
# Out:
#    cars  Mileage
# 0  Ford       10
# 2   Kia       30

# %%
#read csv
df=pd.read_csv(github_csv_url)
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.5
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
pd.options.display.max_rows=10
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.4
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df.head(10)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
# 5        60    102       127     300.5
# 6        60    110       136     374.0
# 7        45    104       134     253.3
# 8        30    109       133     195.1
# 9        60     98       124     269.0

# %%
df.tail()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.4
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
df.size
# Out:
# 676

# %% [markdown]
# # Data cleaning
# Empty cells,
# Data in wrong format,
# Wrong data,
# Duplicates

# %%
#empty cells
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 164 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  164 non-null    int64
#  1   Pulse     164 non-null    int64
#  2   Maxpulse  164 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 6.4 KB

# %%
from numpy import nan
df=pd.read_csv(github_csv_url)
print(df.head())
print(df.info())
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1       600    '20121102'    117       145       NaN
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  34 non-null     int64
#  1   Date      33 non-null     object
#  2   Pulse     34 non-null     int64
#  3   Maxpulse  34 non-null     int64
#  4   Calories  31 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.5+ KB
# None

# %%
df1=df.copy()
df1.fillna({'Calories':100},inplace=True)
print(df1.info())
print(df1.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  34 non-null     int64
#  1   Date      33 non-null     object
#  2   Pulse     34 non-null     int64
#  3   Maxpulse  34 non-null     int64
#  4   Calories  34 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.5+ KB
# None
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1       600    '20121102'    117       145     100.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0

# %%
df2=df.copy()
x=df2['Calories'].mean()
df2.fillna({'Calories':x}, inplace=True)
print(df['Calories']==nan)
print(df2['Calories']==nan)
print(df2.head())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# Name: Calories, Length: 34, dtype: bool
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# Name: Calories, Length: 34, dtype: bool
#    Duration          Date  Pulse  Maxpulse    Calories
# 0        60  '2020/12/01'    110       130  409.100000
# 1       600    '20121102'    117       145  299.506452
# 2        60  '2020/12/03'    103       135  340.000000
# 3        45  '2020/12/04'    109       175  282.400000
# 4        45  '2020/12/05'    117       148  406.000000

# %%
df2['Date']=pd.to_datetime(df2['Date'],format='mixed')
df2['Date']
# Out:
# 0    2020-12-01
# 1    2012-11-02
# 2    2020-12-03
# 3    2020-12-04
# 4    2020-12-05
#         ...
# 29   2020-12-29
# 30   2020-12-30
# 31   2020-12-31
# 32   2020-12-30
# 33   2020-12-31
# Name: Date, Length: 34, dtype: datetime64[ns]

# %%
print(df2['Date']==nan)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# Name: Date, Length: 34, dtype: bool

# %%
print(df[df['Date'].isna()])
# Out:
#     Duration Date  Pulse  Maxpulse  Calories
# 22        45  NaN    100       119     282.0

# %%
df.dropna(subset=['Date'],inplace=True)
print(df[df['Date'].isna()])
# Out:
# Empty DataFrame
# Columns: [Duration, Date, Pulse, Maxpulse, Calories]
# Index: []

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=34, step=1)

# %%
for x in df2.index:
  if df2.loc[x,'Duration']>60:
    df2.loc[x,'Duration']=60
    print('Duration changed at loc', x)

df2['Duration']
# Out:
# Duration changed at loc 1
# Duration changed at loc 7
# 0     60
# 1     60
# 2     60
# 3     45
# 4     45
#       ..
# 29    60
# 30    60
# 31    60
# 32    60
# 33    60
# Name: Duration, Length: 34, dtype: int64

# %%
print(df2.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 29    False
# 30    False
# 31    False
# 32     True
# 33     True
# Length: 34, dtype: bool

# %%
df2.drop_duplicates(inplace=True)
print(df2.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# Length: 31, dtype: bool

# %% [markdown]
# # Data correlation
# The corr() method calculates the relationship between each column in your data set.
#
# method ignores "not numeric" columns.
#
# The number varies from -1 to 1.
#
# 1 means that there is a 1 to 1 relationship (a perfect correlation), and for this data set, each time a value went up in the first column, the other one went up as well.
#
# 0.9 is also a good relationship, and if you increase one value, the other will probably increase as well.
#
# -0.9 would be just as good relationship as 0.9, but if you increase one value, the other will probably go down.
#
# 0.2 means NOT a good relationship, meaning that if one value goes up does not mean that the other will.
#
# -0.6 to 0.6 is a good corrolation

# %%
df2.corr()
# Out:
#           Duration      Date     Pulse  Maxpulse  Calories
# Duration  1.000000  0.265735 -0.057959 -0.231233  0.295583
# Date      0.265735  1.000000  0.077012  0.132728  0.061141
# Pulse    -0.057959  0.077012  1.000000  0.269672  0.380076
# Maxpulse -0.231233  0.132728  0.269672  1.000000  0.257185
# Calories  0.295583  0.061141  0.380076  0.257185  1.000000

# %%
import matplotlib.pyplot as plt
df2.plot()
plt.show()

# %%
# good corrolation
df2.plot(kind='scatter', x='Duration', y='Calories')
plt.show()

# %%
#bad corrolation
df2.plot(kind='scatter',x='Duration', y='Maxpulse')
plt.show()

# %%
df['Duration'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>
