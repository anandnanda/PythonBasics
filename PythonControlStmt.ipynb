# %% [markdown]
# <a href="https://colab.research.google.com/github/anandnanda/PythonBasics/blob/main/PythonControlStmt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#if
a=30
b=30
if a>b:
  print(f"{a} is greater than {b}")
elif b>a:
  print(f"{b} is greater than {a}")
else:
  print(f"{a} equals to {b}")
# Out:
# 30 equals to 30

# %%
#true
c=1
e=-3
# below all false
d=0
f=""
g=None


if c:
  print("c is true")
if e:
  print("e is true")

if d:
  print("d is true")
if f:
  print("f is true")
if g:
  print("g is true")
# Out:
# c is true
# e is true

# %%
print('2') if 2>1  else print('1')
# Out:
# 2

# %%
#'short form of comparison'
a=10
b=11
print(a) if a>b else print('=') if a==b else print(b)
# Out:
# 11

# %%
#pass if no statement
if 34>9:
  pass
else:
  print(9)

# %%
#match (switch case)
import random
rnd=random.randrange(10)
print(rnd)
match rnd:
  case 0:
    print("zero")
  case 1|2|3|4:
    print("1 to 4")
  case _:
    print("> 4 <= 9")
# Out:
# 4
# 1 to 4

# %%
#while
i=0
import random
while i < 5:
  i+=1
  if i==2:
    continue
  elif i==4:
    break
  print(i)


while 1>10:
  print(1)
else:
  print("\nwhile condition not satisfied")
# Out:
# 1
# 3
#
# while condition not satisfied
