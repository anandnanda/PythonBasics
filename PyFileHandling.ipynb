# %% [markdown]
# <a href="https://colab.research.google.com/github/anandnanda/PythonBasics/blob/main/PyFileHandling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # File handling
#
# "r" - Read - Default value. Opens a file for reading, error if the file does not exist
#
# "a" - Append - Opens a file for appending, creates the file if it does not exist
#
# "w" - Write - Opens a file for writing, creates the file if it does not exist
#
# "x" - Create - Creates the specified file, returns an error if the file exists
#
# In addition you can specify if the file should be handled as binary or text mode
#
# "t" - Text - Default value. Text mode
#
# "b" - Binary - Binary mode (e.g. images)

# %% [markdown]
# ### 1. Mount Google Drive
#
# First, you need to mount your Google Drive to access its contents from your Colab notebook. Run the following code cell and follow the prompts to authenticate your Google account.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
# Replace 'my_document.txt' with the actual path to your file in Google Drive
file_path = '/content/drive/My Drive/my_document.txt'

try:
    with open(file_path, 'r') as f:
        content = f.read()
        print("File content:")
        print(content)
except FileNotFoundError:
    print(f"Error: The file '{file_path}' was not found. Please ensure the path is correct and the file exists in your Google Drive.")
except Exception as e:
    print(f"An error occurred: {e}")

# %% [markdown]
# ### 2. Open a File
#
# Once your Drive is mounted, you can access files using their path, typically starting with `/content/drive/My Drive/`.
#
# Here's an example of how to open a text file named `my_document.txt` from the root of your Google Drive and read its content. The file handling modes are explained in the text cell above this one.

# %% [markdown]
# ### 1. Construct the Raw GitHub URL
#
# To access a file's content directly, you need its raw URL. This URL usually follows the format:
#
# `https://raw.githubusercontent.com/{username}/{repository_name}/{branch_name}/{path_to_file}`
#
# For example, if your file is `data/my_data.csv` in the `main` branch of `your_repo` owned by `your_username`, the URL would be:
#
# `https://raw.githubusercontent.com/your_username/your_repo/main/data/my_data.csv`

# %% [markdown]
# ### 2. Read the File Content
#
# Now, you can use the `requests` library to download the content of the file.

# %%
import requests

# Replace with the actual raw URL of your GitHub file
github_file_url = 'https://raw.githubusercontent.com/anandnanda/PythonBasics/main/SampleTxtFile.txt'

try:
    response = requests.get(github_file_url)
    response.raise_for_status()  # Raise an HTTPError for bad responses (4xx or 5xx)

    file_content = response.text
    print("File content:")
    print(file_content)

except requests.exceptions.HTTPError as errh:
    print(f"HTTP Error: {errh}")
except requests.exceptions.ConnectionError as errc:
    print(f"Error Connecting: {errc}")
except requests.exceptions.Timeout as errt:
    print(f"Timeout Error: {errt}")
except requests.exceptions.RequestException as err:
    print(f"Something went wrong: {err}")
# Out:
# File content:
# This is a sample text file

# %% [markdown]
# Remember to replace `github_file_url` with the actual raw URL of the file you want to read from GitHub. If it's a CSV or other structured data, you might use `pd.read_csv()` from pandas with this URL directly after importing pandas.

# %%
import requests

gitHubFile='https://raw.githubusercontent.com/anandnanda/PythonBasics/main/SampleTxtFile.txt'
response=requests.get(gitHubFile,'rt')
print(response.text)
# Out:
# This is a sample text file

# %%
print(response.content)
# Out:
# b'This is a sample text file\n'

# %%
response.close()

# %%
print(response.text)
# Out:
# This is a sample text file

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1853699498.py in <cell line: 0>()
#       1 responseWrite=requests.get(gitHubFile,'w')
# ----> 2 responseWrite.text="This is new content"
#       3 print(responseWrite.text)
#
# AttributeError: property 'text' of 'Response' object has no setter
